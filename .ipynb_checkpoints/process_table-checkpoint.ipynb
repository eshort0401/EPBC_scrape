# %%
import pandas as pd
import numpy as np
import re
from rapidfuzz import fuzz, process, utils
import matplotlib.pyplot as plt
import os
import process_table
import glob

# %%
# %load_ext autoreload
# %autoreload 2
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
if os.name == 'nt':
    base_dir = 'C:/Users/{}/'.format(os.getlogin())
    base_dir += 'Documents/ACF_consulting/'
else:
    base_dir = '/home/student.unimelb.edu.au/shorte1/Documents/'
    base_dir += 'ACF_consulting'

# %%
table, f_table = process_table.get_new_rows(base_dir)

# %%
table
# Out:
#    Reference Number                                  Title of referral  \
# 0         2021/8977  Elizabeth Borrello/Commercial Development/Flyn...
# 1         2021/8910  Mt Fox Energy Park Pty Ltd/Energy Generation a...
# 2         2021/8915  Water Corporation/Water Management and Use/358...
# 3         2021/8948  The Trustee for Manyana Property Trust/Residen...
# 4         2021/8948  The Trustee for Manyana Property Trust/Residen...
# 5         2021/8969  Byron Shire Council/Waste Management (sewerage...
# 6         2021/8910  Mt Fox Energy Park Pty Ltd/Energy Generation a...
# 7         2017/8070  Department of Economic Development, Jobs, Tran...
# 8         2020/8692  Queensland Department of Transport and Main Ro...
# 9         2021/8920  Yancoal Australia Ltd/Mining/Dysart Middlemoun...
# 10        2021/8920  Yancoal Australia Ltd/Mining/Dysart Middlemoun...
# 11        2020/8849  Lendlease Communities (Shoreline) Pty Ltd/Wast...
# 12        2021/8973  Metka EGN Australia Pty Ltd/Energy Generation ...
# 13        2021/8975  Osprey Property Pty Ltd/Residential Developmen...
# 14        2021/8971  WESTERN AREAS LIMITED/Mining/Forrestania/Weste...
# 15        2021/8965  CAPITAL PLUS 1 WOODBURY RIDGE PTY LTD/Resident...
# 16        2021/8968  Stevens Holdings Pty Ltd/Residential Developme...
# 17        2019/8563  DEPARTMENT OF TRANSPORT/Transport - Land/near ...
# 19        2021/8891  NW Interconnected Power Pty Ltd/Energy Generat...
# 20        2019/8516  WEIYA DEVELOPMENT PTY LIMITED/Residential Deve...
# 21        2019/8425  AGL ENERGY LIMITED/Energy Generation and Suppl...
# 22        2019/8529  MAIN ROADS/Transport - Land/Hale Road, Forrest...
# 23        2021/8919  South Australian Water Corporation/Water Manag...
# 24        2021/8955  Polaris Metals Pty Ltd/Mining/Parker Range Iro...
# 25        2021/8972  Crookwell 3 Development Pty Ltd/Energy Generat...
# 26        2021/8946  Gold Coast Hospital and Health Service/Science...
# 27        2021/8967  Main Roads Western Australia/Transport - Land/...
# 28        2021/8943  Department of Transport/Transport - Land/VicTr...
# 29        2018/8260  WESTERN REGION WATER CORPORATION/Water Managem...
#
#                            Notification from EPBC Act Date of notice  \
# 0           Invitation for Public Comment on Referral     22/06/2021
# 1   Decision on Assessment Approach: Preliminary D...     18/06/2021
# 2           Invitation for Public Comment on Referral     18/06/2021
# 3   Decision whether action needs approval/Approva...     18/06/2021
# 4   Decision on Assessment Approach: Preliminary D...     18/06/2021
# 5    Suspension of Referral Decision Timeframe Period     18/06/2021
# 6   Decision whether action needs approval/Approva...     18/06/2021
# 7               Notification of Variation to Approval     17/06/2021
# 8   Decision on approval of action: Approved with ...     17/06/2021
# 9   Decision on Assessment Approach: Preliminary D...     17/06/2021
# 10  Decision whether action needs approval/Approva...     17/06/2021
# 11   Suspension of Referral Decision Timeframe Period     16/06/2021
# 12          Invitation for Public Comment on Referral     16/06/2021
# 13          Invitation for Public Comment on Referral     16/06/2021
# 14          Invitation for Public Comment on Referral     15/06/2021
# 15          Invitation for Public Comment on Referral     15/06/2021
# 16          Invitation for Public Comment on Referral     15/06/2021
# 17              Final recommendation report completed     15/06/2021
# 19          Decision on referral/clearly unacceptable     15/06/2021
# 20  Notification of Publication of Final Prelimina...     14/06/2021
# 21  Assessment Process Notice: Extension of time i...     11/06/2021
# 22  Notification of Publication of Final Prelimina...     10/06/2021
# 23  Decision whether action needs approval/Approva...     10/06/2021
# 24          Invitation for Public Comment on Referral     10/06/2021
# 25          Invitation for Public Comment on Referral     10/06/2021
# 26          Invitation for Public Comment on Referral     10/06/2021
# 27          Invitation for Public Comment on Referral     10/06/2021
# 28  Decision whether action needs approval/Approva...     09/06/2021
# 29                            Correction notification     09/06/2021
#
#    PDF Attachments Non PDF Attachments        Download  \
# 0              Yes                  No         Success
# 1              Yes                  No         Success
# 2              Yes                  No         Success
# 3              Yes                  No         Success
# 4              Yes                  No         Success
# 5              Yes                  No         Success
# 6              Yes                  No         Success
# 7              Yes                  No         Success
# 8              Yes                  No         Success
# 9              Yes                  No         Success
# 10             Yes                  No         Success
# 11             Yes                  No         Success
# 12             Yes                  No         Success
# 13             Yes                  No         Success
# 14             Yes                  No         Success
# 15             Yes                  No         Success
# 16             Yes                  No         Success
# 17              No                  No  Not Applicable
# 19             Yes                  No         Success
# 20             Yes                  No         Success
# 21             Yes                  No         Success
# 22             Yes                  No         Success
# 23             Yes                  No         Success
# 24             Yes                  No         Success
# 25             Yes                  No         Success
# 26             Yes                  No         Success
# 27             Yes                  No         Success
# 28             Yes                  No         Success
# 29             Yes                  No         Success
#
#                              Download Folder   PDFs Combined  \
# 0                20218977_22062021_eb_ifpcor             Yes
# 1            20218910_18062021_mfeppl_doaapd             Yes
# 2                20218915_18062021_wc_ifpcor             Yes
# 3           20218948_18062021_ttfmpt_dwanaar             Yes
# 4            20218948_18062021_ttfmpt_doaapd             Yes
# 5               20218969_18062021_bsc_sordtp             Yes
# 6           20218910_18062021_mfeppl_dwanaar             Yes
# 7          20178070_17062021_doedjtarv_novta             Yes
# 8         20208692_17062021_qdotamr_doaoaawc             Yes
# 9               20218920_17062021_yal_doaapd             Yes
# 10             20218920_17062021_yal_dwanaar             Yes
# 11            20208849_16062021_lcspl_sordtp             Yes
# 12            20218973_16062021_meapl_ifpcor             Yes
# 13             20218975_16062021_oppl_ifpcor             Yes
# 14              20218971_15062021_wal_ifpcor             Yes
# 15          20218965_15062021_cp1wrpl_ifpcor             Yes
# 16             20218968_15062021_shpl_ifpcor             Yes
# 17                            Not Applicable  Not Applicable
# 19             20218891_15062021_nippl_dorcu             Yes
# 20            20198516_14062021_wdpl_nopofpd             Yes
# 21  20198425_11062021_ael_apneotiwtmadwtaaca             Yes
# 22              20198529_10062021_mr_nopofpd             Yes
# 23           20218919_10062021_sawc_dwanaanr             Yes
# 24             20218955_10062021_pmpl_ifpcor             Yes
# 25            20218972_10062021_c3dpl_ifpcor             Yes
# 26           20218946_10062021_gchahs_ifpcor             Yes
# 27             20218967_10062021_mrwa_ifpcor             Yes
# 28            20218943_09062021_dot_dwanaanr             Yes
# 29                 20188260_09062021_wrwc_cn             Yes
#
#                                       Approval Holder  \
# 0                                  Elizabeth Borrello
# 1                          Mt Fox Energy Park Pty Ltd
# 2                                   Water Corporation
# 3              The Trustee for Manyana Property Trust
# 4              The Trustee for Manyana Property Trust
# 5                                 Byron Shire Council
# 6                          Mt Fox Energy Park Pty Ltd
# 7   Department of Economic Development, Jobs, Tran...
# 8   Queensland Department of Transport and Main Roads
# 9                               Yancoal Australia Ltd
# 10                              Yancoal Australia Ltd
# 11          Lendlease Communities (Shoreline) Pty Ltd
# 12                        Metka EGN Australia Pty Ltd
# 13                            Osprey Property Pty Ltd
# 14                              WESTERN AREAS LIMITED
# 15              CAPITAL PLUS 1 WOODBURY RIDGE PTY LTD
# 16                           Stevens Holdings Pty Ltd
# 17                            DEPARTMENT OF TRANSPORT
# 19                    NW Interconnected Power Pty Ltd
# 20                      WEIYA DEVELOPMENT PTY LIMITED
# 21                                 AGL ENERGY LIMITED
# 22                                         MAIN ROADS
# 23                 South Australian Water Corporation
# 24                             Polaris Metals Pty Ltd
# 25                    Crookwell 3 Development Pty Ltd
# 26             Gold Coast Hospital and Health Service
# 27                       Main Roads Western Australia
# 28                            Department of Transport
# 29                   WESTERN REGION WATER CORPORATION
#
#                                         Industry  \
# 0                         Commercial Development
# 1       Energy Generation and Supply (renewable)
# 2                       Water Management and Use
# 3                        Residential Development
# 4                        Residential Development
# 5                    Waste Management (sewerage)
# 6       Energy Generation and Supply (renewable)
# 7                               Transport - Land
# 8                              Transport - Water
# 9                                         Mining
# 10                                        Mining
# 11                   Waste Management (sewerage)
# 12      Energy Generation and Supply (renewable)
# 13                       Residential Development
# 14                                        Mining
# 15                       Residential Development
# 16                       Residential Development
# 17                              Transport - Land
# 19      Energy Generation and Supply (renewable)
# 20                       Residential Development
# 21  Energy Generation and Supply (non-renewable)
# 22                              Transport - Land
# 23                      Water Management and Use
# 24                                        Mining
# 25      Energy Generation and Supply (renewable)
# 26                          Science and Research
# 27                              Transport - Land
# 28                              Transport - Land
# 29                      Water Management and Use
#
#                                        Holder Address              State  \
# 0                               Flynn drive, Neerabup  Western Australia
# 1                                         , Mount Fox         Queensland
# 2           358 Vase-yallingup Siding Road, Marybrook  Western Australia
# 3   approximately 0.5 km north of the township of ...    New South Wales
# 4   approximately 0.5 km north of the township of ...    New South Wales
# 5                          45 Wallum Place, Byron Bay    New South Wales
# 6                                         , Mount Fox         Queensland
# 7   Lot 1 and 2 of Title Plan 333725, Crown Allotm...           Victoria
# 8             Road Reserve and Unallocated State Land         Queensland
# 9                Dysart Middlemount Road, Middlemount         Queensland
# 10               Dysart Middlemount Road, Middlemount         Queensland
# 11  Longland Road to Serpentine Creek Road, Redlan...         Queensland
# 12                       17235 Dawson Highway, Banana         Queensland
# 13    between Hunt Road and Rossetta Road, Burpengary         Queensland
# 14                                        Forrestania  Western Australia
# 15  adjacent to Sutton Road and Federal Highway, S...    New South Wales
# 16                         414 Old Maitland Rd, Mardi    New South Wales
# 17                                      near Pakenham           Victoria
# 19  After Mandora Road on Great Northern Highway, ...  Western Australia
# 20    Lot 801 on SP157194, Lot 1 and Lot 2 on RP22251         Queensland
# 21  Lots 2 and 3 DP 1043561, Lot 4 DP 1043561, Lot...    New South Wales
# 22  Hale Road, Forrestfield and Welshpool Road, Wa...  Western Australia
# 23  , Playford Highway; Arronmore Rd; How Bay Rd, ...    South Australia
# 24  Parker Range Iron Ore Mine to Koolyanobbing Op...  Western Australia
# 25                794 Woodhouselee Road, Woodhouselee    New South Wales
# 26                   41 George Alexander Way, Coomera         Queensland
# 27                  Yardie Creek Rd, Shire of Exmouth  Western Australia
# 28  VicTrack Rail Reserve, McGregor Road, Main Str...           Victoria
# 29  Plan CP104323, Lot 20 LP5327, Allot. 19 Sec. A...           Victoria
#
#                                           Description
# 0   Subdivision of Lot 902 Flynn Drive Neerabup fo...
# 1                   Mt Fox Energy Park Wind Farm, QLD
# 2           Lennox Weir Removal, 12kms west Busselton
# 3                      North Manyana Subdivision, NSW
# 4                      North Manyana Subdivision, NSW
# 5                      Byron Shire Bioenergy Facility
# 6                   Mt Fox Energy Park Wind Farm, QLD
# 7   South Gippsland Highway Realignment, Koonwarra...
# 8         Yorkeys Knob Boating Infrastructure Project
# 9   Middlemount Coal Mine - Southern Open Cut Exte...
# 10  Middlemount Coal Mine - Southern Open Cut Exte...
# 11    Southern Redland Bay Wastewater Treatment Plant
# 12                                   Moura Solar Farm
# 13    Hunt Road, Burpengary - Residential Development
# 14     New Morning Underground Nickel Deposit Project
# 15                      Woodbury Ridge Estate, Sutton
# 16      414 Old Maitland Road Residential Subdivision
# 17  Gippsland Rail Line Upgrade - Pakenham to Long...
# 19    Asian Renewable Energy Hub Revised Proposal, WA
# 20  Residential Development, Collingwood Park, Ips...
# 21       Newcastle Power Station Project, Tomago, NSW
# 22        Tonkin Highway Grade Separated Interchanges
# 23                      KI Water Pipeline Project, SA
# 24  Parker Range Mt Caudan Iron Ore Haul Road Prop...
# 25                              Crookwell 3 Wind Farm
# 26               Coomera Hospital and Health Precinct
# 27              Yardie Creek Road Realignment Project
# 28            Pakenham Level Crossing Removal Project
# 29                     Parwan to Melton Pipeline, VIC

# %%
table = process_table.format_title(base_dir, table)

# %%
process_table.get_company_databases(base_dir)

# %%
table = process_table.lookup_ASIC_data(base_dir, table)
# Out:
# Preprocessing text match tokens. Please wait.
# Performing fuzzy text match. Please wait.
# > c:\users\eshor\documents\acf_consulting\process_table.py(198)lookup_ASIC_data()
#     196
#     197     import pdb; pdb.set_trace()
# --> 198     table.insert(7, 'Registered Name', ASIC_name)
#     199     table.insert(8, 'Type', com_type)
#     200     table.insert(9, 'ABN', ABN)
#
# ipdb> n
# > c:\users\eshor\documents\acf_consulting\process_table.py(199)lookup_ASIC_data()
#     197     import pdb; pdb.set_trace()
#     198     table.insert(7, 'Registered Name', ASIC_name)
# --> 199     table.insert(8, 'Type', com_type)
#     200     table.insert(9, 'ABN', ABN)
#     201     table.insert(10, 'ACN', ACN)
#
# ipdb> n
# > c:\users\eshor\documents\acf_consulting\process_table.py(200)lookup_ASIC_data()
#     198     table.insert(7, 'Registered Name', ASIC_name)
#     199     table.insert(8, 'Type', com_type)
# --> 200     table.insert(9, 'ABN', ABN)
#     201     table.insert(10, 'ACN', ACN)
#     202     table.ABN.loc[table['ABN'] == '0'] = 'Not Applicable'
#
# ipdb> n
# > c:\users\eshor\documents\acf_consulting\process_table.py(201)lookup_ASIC_data()
#     199     table.insert(8, 'Type', com_type)
#     200     table.insert(9, 'ABN', ABN)
# --> 201     table.insert(10, 'ACN', ACN)
#     202     table.ABN.loc[table['ABN'] == '0'] = 'Not Applicable'
#     203
#
# ipdb> n
# > c:\users\eshor\documents\acf_consulting\process_table.py(202)lookup_ASIC_data()
#     200     table.insert(9, 'ABN', ABN)
#     201     table.insert(10, 'ACN', ACN)
# --> 202     table.ABN.loc[table['ABN'] == '0'] = 'Not Applicable'
#     203
#     204     f_table = pd.read_csv(base_dir + 'revised_table.csv', dtype=str, sep='\t')
#
# ipdb> n
# > c:\users\eshor\documents\acf_consulting\process_table.py(204)lookup_ASIC_data()
#     202     table.ABN.loc[table['ABN'] == '0'] = 'Not Applicable'
#     203
# --> 204     f_table = pd.read_csv(base_dir + 'revised_table.csv', dtype=str, sep='\t')
#     205     table['Date of notice'] = pd.to_datetime(
#     206         table['Date of notice'], dayfirst=True)
#
# ipdb> c

# %%
fig_app, ax_app = plt.subplots(figsize=(10, 6))
theme = plt.get_cmap('Pastel1')
ax_app.set_prop_cycle("color", [theme(1. * i / len(holder_counts))
                             for i in range(len(holder_counts))])
plt.pie(holder_counts, labels=holder_labels, autopct='%1.2f%%', explode=[.2,.2,.2])
plt.title('Total Referrals by Organisation Type')

plt.savefig(base_dir + '/example_figure.pdf', format='pdf')

# fig_ASIC, ax_ASIC = plt.subplots(figsize=(6, 6))
# theme = plt.get_cmap('Pastel1')
# ax_ASIC.set_prop_cycle("color", [theme(1. * i / len(totals))
#                              for i in range(len(totals))])
# ax_pie.set_prop_cycle("color", [theme(1. * i / len(totals))
#                              for i in range(len(types))])
# plt.pie(totals, labels=types, autopct='%1.2f%%', explode=[.2]*len(types))

# %%
import urllib
import json
url = 'https://data.gov.au/data/api/3/action/datastore_search?resource_id=eb1e6be4-5b13-4feb-b28e-388bf7c26f93&limit=200000'  
fileobj = urllib.request.urlopen(url)
ACNC_register = pd.DataFrame(json.loads(fileobj.read())['result']['records'])

# %%
ACNC_register.to_csv(base_dir + 'test.csv')

# %%
url = 'https://data.gov.au/data/api/3/action/datastore_search?resource_id=cb7e4eb5-ed46-4c6c-97a0-4532f4479b7d&limit=1000000'
fileobj = urllib.request.urlopen(url)
ASIC_register = pd.DataFrame(json.loads(fileobj.read())['result']['records'])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-16-b879e803c49f> in <module>
#       1 url = 'https://data.gov.au/data/api/3/action/datastore_search?resource_id=cb7e4eb5-ed46-4c6c-97a0-4532f4479b7d&limit=1000000'
# ----> 2 fileobj = urllib.request.urlopen(url)
#       3 ASIC_register = pd.DataFrame(json.loads(fileobj.read())['result']['records'])
#
# ~\miniconda3\envs\acf\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\miniconda3\envs\acf\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# ~\miniconda3\envs\acf\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# ~\miniconda3\envs\acf\lib\urllib\request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# ~\miniconda3\envs\acf\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~\miniconda3\envs\acf\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 502: Bad Gateway

# %%
ASIC_register
